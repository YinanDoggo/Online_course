# %% [markdown]
# # Week 2
# ## Matplotlib

# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
mpl.get_backend()

# The Backend Layer is in charge of actual plotting, the Artist Layers describes the way to arrange data (using dots and lines)
# and finally the Scripting Layers creats the artists and conduct their actions
# Out:
# 'nbAgg'

# %%
# declarative and procedural method for visualizations

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
plt.plot(2,3)

# %%
plt.plot(2,3,".") # older backend instaed of the current interactive backend does not update the current plot and instead create a new one, which might also be useful.

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvasAgg(fig)

ax = fig.add_subplot(111)
ax.plot(3,2,'.')
canvas.print_png('test.png')

# %%
# %%html
# <img scr='test.png' />

# %%
plt.figure()
plt.plot(3,2,'x')
ax = plt.gca()
ax.axis([0,6,0,10])

# %%
plt.figure()
plt.plot(2,4,'o')
plt.plot(3,6,'o')
plt.plot(1,2,'x')

# %%
ax = plt.gca()
ax.get_children()

# %% [markdown]
# # Scatterplots

# %%
import numpy as np
x = np.array([1,2,3,4,5,6])
y = x
plt.figure()
plt.scatter(x,y)

# %%
x = np.array([1,2,3,4,5,6,7,8])
y = x
colors = ["green"]*(len(x)-1)
colors.append('red')

plt.figure()
plt.scatter(x, y, s=100, c=colors)

# %%
zip_generator = zip([1,2,3,4],[5,6,7,8])
list(zip_generator)

# %%
zip_generator = zip([1,2,3,4],[5,6,7,8])
x,y = zip(*zip_generator)
print(x)
print(y)

# %%
plt.figure()
plt.scatter(x[:2], y[:2], s=100, c="red", label="Tall students")
plt.scatter(x[2:], y[2:], s=100, c="blue", label="Short students")

# %%
plt.xlabel("the number of times the child kicked a ball")
plt.ylabel("the grade of the student")
plt.title("Relationship between ball kicking and grades")

# %%
plt.legend()

# %%
plt.legend(loc=4, frameon=False, title="Legend")

# %%
plt.gca().get_children()

# %%
legend = plt.gca().get_children()[-2]

# %%
legend.get_children()[0].get_children()[1].get_children()[0].get_children()

# %%
from matplotlib.artist import Artist

def rec_gc(art, depth=0):
    if isinstance(art, Artist):
        print("  " * depth + str(art))
        for child in art.get_children():
            rec_gc(child, depth+2)
rec_gc(legend)

# %% [markdown]
# # Line Plots

# %%
import numpy as np

linear_data = np.array([1,2,3,4,5,6,7,8])
quadratic_data = linear_data**2

plt.figure()
plt.plot(linear_data, "-o", quadratic_data, "-o")

# %%
plt.plot([20,30,40], "--r")

# %% [markdown]
# ## Adding Legend

# %%
plt.xlabel("index")
plt.ylabel("value of data")
plt.title("name of the graph")
plt.legend(["linear","quadratic","dash"])

# %% [markdown]
# ##  Fill Between Function

# %%
plt.gca().fill_between(range(len(linear_data)),
                      linear_data, quadratic_data,
                      facecolor="grey", alpha=0.5)

# %%
plt.figure()

observation_dates = np.arange("2018-01-01", "2018-01-09", dtype='datetime64[D]')

plt.plot(observation_dates, linear_data, '-o',
        observation_dates, quadratic_data, '-o')

# %%
import pandas as pd

plt.figure()

observation_dates = np.arange("2018-01-01", "2018-01-09", dtype='datetime64[D]')
observation_dates = map(pd.to_datetime, observation_dates)

plt.plot(observation_dates, linear_data, '-o',
        observation_dates, quadratic_data, '-o')

# %%
plt.figure()

observation_dates = np.arange("2018-01-01", "2018-01-09", dtype='datetime64[D]')
observation_dates = list(map(pd.to_datetime, observation_dates))

plt.plot(observation_dates, linear_data, '-o',
        observation_dates, quadratic_data, '-o')

# %%
x = plt.gca().xaxis
depth = 0
for child in x.get_children():
    rec_gc(child, depth+2)
rec_gc(legend)

# %%
x = plt.gca().xaxis
for item in x.get_ticklabels():
    item.set_rotation(45)

# %%
plt.subplots_adjust(bottom=0.25)

# %% [markdown]
# ## Bar Charts

# %%
plt.figure()
xval = range(len(linear_data))
plt.bar(xval, linear_data, width=0.3)

# %%
xval_new = []
for item in xval:
    xval_new.append(item+0.3)

plt.bar(xval_new, quadratic_data, width=0.3, color="red")

# %%
from random import randint
linear_err = [randint(0,15) for x in range(len(linear_data))]
plt.bar(xval, linear_data, width=0.3, yerr=linear_err)

# %%
plt.figure()
xvals = range(len(linear_data))
plt.bar(xvals, linear_data, width=0.3, color="b")
plt.bar(xvals, quadratic_data, width=.3, bottom=linear_data, color="r")

# %%
plt.figure()
xvals = range(len(linear_data))
plt.barh(xvals, linear_data, height=0.3, color="b")
plt.barh(xvals, quadratic_data, height=.3, left=linear_data, color="r")

# %% [markdown]
# # Dejunkifying Plot

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages = ['Python','SQL','Java','C++','JavaScript']
pos = np.arange(len(languages))
popularity = [56,39,34,34,29]
# TODO: change the bar colors to be less brigh blue
# TODO: make one bar, the python bar, a contrasting color
barplot = plt.bar(pos, popularity, align='center', color='lightslategrey')
barplot[0].set_color("r")

#TODO: soften all lables by turning grey
plt.title('title', color='grey')
plt.xticks(pos, languages, alpha=0.8)
plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overfllow', alpha=0.8)

#remove all the ticks(both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

#remove frame around the figure
for spine in plt.gca().spines.values():
    spine.set_visible(False)
    
#direct lable each bar with Y axis values
for bar in barplot:
    plt.gca().text(bar.get_x()+bar.get_width()/2, bar.get_height()-5, str(int(bar.get_height())) + '%',
                  ha='center', color='w', fontsize=11)
plt.show()
# Out:
# C:\Users\YZ\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # Week 3

# %% [markdown]
# ## Subplots

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

plt.subplot?

# %% [markdown]
# creat a figure and 2 subplot with index 2
#
# indicate which subplot by index

# %%
plt.figure()
plt.subplot(1,2,1)

linear_data = np.array([1,2,3,4,5,6,7,8])

plt.plot(linear_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# same for subplot "2"

# %%
exponential_data = linear_data**2

plt.subplot(1,2,2)
plt.plot(exponential_data, '-o')

# %% [markdown]
# call back anytime a subplot by index plt.subplot(1,2,index) and do some changes

# %%
plt.subplot(1,2,1)
plt.plot(exponential_data, '-x')
# Out:
# C:\Users\YZ\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# How to lock axis to prevent confusion due to different axis scale

# %%
plt.figure()
ax1 = plt.subplot(1,2,1) #store axis of subplot 1
plt.plot(linear_data, '-o')
ax2 = plt.subplot(1,2,2, sharey=ax1) #indicating subplot2 share the same y axis with subplot2
plt.plot(exponential_data, '-x')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# create shared axis/axes at once for multiple subplots

# %%
fig, ((ax1,ax2,ax3), (ax4,ax5,ax6), (ax7,ax8,ax9)) = plt.subplots(3, 3, sharex=True, sharey=True)

ax5.plot(exponential_data, '-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# force the hidden axis to show on every subplots using loop to access the .gcf()

# %%
for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(True)

# %% [markdown]
# nothing happen because the above command doesn't redraw the function. Insteand using canvas draw function

# %%
plt.gcf().canvas.draw()

# %% [markdown]
# still nothing happens...

# %% [markdown]
# ## Histogram

# %%
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(2,2,sharex=True)
axs = [ax1,ax2,ax3,ax4]

for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size=sample_size) # randomly normally distributed variable with mean(loc) 0 and std(scale) 1
    axs[n].hist(sample)
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# change bins size

# %%
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(2,2,sharex=True)
axs = [ax1,ax2,ax3,ax4]

for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size=sample_size) # randomly normally distributed variable with mean(loc) 0 and std(scale) 1
    axs[n].hist(sample, bins=100) #change bin size with bins=
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## GridSpce

# %%
plt.figure()
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
plt.scatter(X,Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.gridspec as gridspec
plt.figure()
gspec = gridspec.GridSpec(3,3)

top_histogram = plt.subplot(gspec[0,1:]) #index starts now with 0
side_histogram = plt.subplot(gspec[1:,0])
lower_right = plt.subplot(gspec[1:,1:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
lower_right.scatter(X,Y)
top_histogram.hist(X, bins=100)
s = side_histogram.hist(Y, bins=100, orientation='horizontal') #rotate the orientation

# %% [markdown]
# remove y axis from the top right histogram and the y axis from the bottom left grpah since these are probability density histogram, we only care about the relative values. Clear it.

# %%
top_histogram.clear()
top_histogram.hist(X, bins=100, normed=True) #normed=True to tell .hist to scale the probability value between 0 and 1
side_histogram.clear()
side_histogram.hist(Y, bins=100, orientation='horizontal', normed=True)

side_histogram.invert_xaxis() #invert x axis
# Out:
# C:\Users\YZ\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# set limit to axis to define same scale for x and y axis for the three plots

# %%
for ax in [top_histogram, lower_right]:
    ax.set_xlim(0,1)
for ax in [side_histogram, lower_right]:
    ax.set_ylim(-5,5)

# %% [markdown]
# ## Boxplot

# %%
import pandas as pd
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal':normal_sample,
                  'random':random_sample,
                  'gamma':gamma_sample})

# %% [markdown]
# use .describe() for simple statistical report

# %%
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean       0.003233      0.502228      1.987388
# std        0.994398      0.289234      1.404000
# min       -3.563676      0.000113      0.004500
# 25%       -0.682488      0.252787      0.959503
# 50%       -0.002132      0.508254      1.685620
# 75%        0.673515      0.751568      2.657829
# max        3.983360      0.999871     10.626995

# %% [markdown]
# the symbole _ is conventionaly used to assign value that one doesn't care and won't use later

# %%
plt.figure()
_ = plt.boxplot(df['normal'], whis='range') #whis='range' tells the boxplot to set the range to minimal and maximal
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.clf()
_ = plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')

# %% [markdown]
# The boxplot of the random variables following gamma distrubtion looks weird. Plot a histogram of it to show the long tail

# %%
plt.figure()
_ = plt.hist(df['gamma'], bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Use axis grid to lay the histogram on top of the boxplot

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')
ax2 = mpl_il.inset_axes(plt.gca(), width='60%', height='40%', loc=2)
ax2.hist(df['gamma'], bins=100)
ax2.margins(x=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# sort out the overlapping y axis problem using yaxis.tick_right() function

# %%
ax2.yaxis.tick_right()

# %% [markdown]
# Silence whis='range' to detect outliers

# %%
plt.figure()
_ = plt.boxplot([df['normal'], df['random'], df['gamma']])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Adding noches to the plot to indicate confidence interval of the data. Read the documentation for more.

# %% [markdown]
# # Heatmap

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

Y = np.random.normal(loc=0.0,scale=1.0,size=10000)
X = np.random.random(size=10000)
_ = plt.hist2d(X,Y,bins=25)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
_ = plt.hist2d(X,Y,bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.colorbar()

# %% [markdown]
# # Animations

# %%
import matplotlib.animation as animation
import numpy as np
import matplotlib.pyplot as plt 

n = 100
x = np.random.randn(n)

# %%
def update(curr):
    if curr == n:
        a.event_source.stop()
    plt.cla()
    bins = np.arange(-4,4,0.5)
    plt.hist(x[:curr],bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlable('Value')
    plt.annotate('n = {}'.format(curr),[3,27]) #to show in the animation which curr is currently sampled

# %%
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval=100) #interval=100 update every 100 milisecond
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Interactivity

# %%
plt.figure()
data = np.random.rand(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixels {},{} {}and data {},{}'.format(event.x,
                                                                       event.y,
                                                                       '\n',
                                                                       event.xdata,
                                                                       event.ydata))
    
plt.gcf().canvas.mpl_connect('botton_press_event',onclick) #connect to event listener through wiring up
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 7

# %%
from random import shuffle
import pandas as pd
origins = ['China','Brazil','India','USA','Canada','UK','Germany','Iraq','Chile','Mexico']

shuffle(origins)

df = pd.DataFrame({'height':np.random.rand(10),
                  'weight':np.random.rand(10),
                   'origin':origins})

df
# Out:
#      height    weight   origin
# 0  0.385074  0.116192    India
# 1  0.317858  0.652469       UK
# 2  0.843952  0.117997  Germany
# 3  0.082303  0.485547    China
# 4  0.285769  0.088022      USA
# 5  0.242368  0.070727   Mexico
# 6  0.847391  0.307361     Iraq
# 7  0.624228  0.906506   Canada
# 8  0.692691  0.725608   Brazil
# 9  0.289958  0.695815    Chile

# %%
plt.figure()
plt.scatter(df['height'],df['weight'],picker=5) #picker defines the pixels near the data point to activate the animation
plt.gca().set_ylabel('Weight')
plt.gca().set_xlabel('Height')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5,0,'Height')

# %%
def onpick(event):
    origin = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title('Selected item came from {}'.format(origin))
plt.gcf().canvas.mpl_connect('pick_event',onpick)
# Out:
# 7
