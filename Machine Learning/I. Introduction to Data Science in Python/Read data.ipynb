# %%
import numpy as np
import pandas as pd
import os as os

name = os.path.abspath('f56_pollutant_prices')
df = pd.read_csv(name + '.csv')
print(df.columns)


#column_list = df.iloc[:,0:3033].columns.values.tolist()
#for column_name in column_list:
#    result = df[column_name].unique()
#    print(result)
df.loc[df['dummy'] == 'y2030'].filter(like='SSP1-')

#writer = pd.ExcelWriter(name + '.xlsx')
#df.to_excel(writer,'Sheet1', index=False)
#writer.save()
# Out:
# Index(['dummy', 'dummy.1', 'dummy.2', 'SSP1-20-SPA1-V15-IMAGE',
#        'SSP1-26-SPA1-V15-IMAGE', 'SSP1-34-SPA1-V15-IMAGE',
#        'SSP1-45-SPA1-V15-IMAGE', 'SSP1-Ref-SPA0-V15-IMAGE',
#        'SSP1-20-SPA1-V15-REMIND-MAGPIE', 'SSP1-26-SPA1-V15-REMIND-MAGPIE',
#        'SSP1-34-SPA1-V15-REMIND-MAGPIE', 'SSP1-37-SPA1-V15-REMIND-MAGPIE',
#        'SSP1-45-SPA1-V15-REMIND-MAGPIE', 'SSP1-Ref-SPA0-V15-REMIND-MAGPIE',
#        'SSP2-18-SPA2-V15-MESSAGE-GLOBIOM', 'SSP2-19-SPA2-V15-MESSAGE-GLOBIOM',
#        'SSP2-20-SPA2-V15-MESSAGE-GLOBIOM', 'SSP2-26-SPA2-V15-MESSAGE-GLOBIOM',
#        'SSP2-34-SPA2-V15-MESSAGE-GLOBIOM', 'SSP2-45-SPA2-V15-MESSAGE-GLOBIOM',
#        'SSP2-60-SPA2-V15-MESSAGE-GLOBIOM', 'SSP2-Ref-SPA0-V15-MESSAGE-GLOBIOM',
#        'SSP2-20-SPA2-V15-REMIND-MAGPIE', 'SSP2-26-SPA2-V15-REMIND-MAGPIE',
#        'SSP2-34-SPA2-V15-REMIND-MAGPIE', 'SSP2-37-SPA2-V15-REMIND-MAGPIE',
#        'SSP2-45-SPA2-V15-REMIND-MAGPIE', 'SSP2-60-SPA2-V15-REMIND-MAGPIE',
# ...

# %%
import pandas as pd
import os as os
import xlsxwriter

name = os.path.abspath('AgMip_CAPRI_results_20180621')
df = pd.read_excel(name + '.xlsx')

print(df.shape)

column_list = df.iloc[:,4:5].columns.values.tolist()
for column_name in column_list:
    result = df[column_name].unique()
print(result)


'''
workbook = xlsxwriter.Workbook('arrays.xlsx')
worksheet = workbook.add_worksheet()

array = result

row = 0

for col, data in enumerate(array):
    worksheet.write_column(row, col, data)

workbook.close()'''
# Out:
# (46459, 8)
# ['XPRC' 'CONS' 'FOOD' 'OTHU' 'CALO' 'XPRP' 'XPRX' 'AREA' 'PROD' 'FEED'
#  'YEXO' 'YILD' 'EMIS' 'EN2O' 'ECH4' 'POPT' 'GDPT' 'TPRD' 'TGHG' 'TN2O'
#  'TCH4']
# "\nworkbook = xlsxwriter.Workbook('arrays.xlsx')\nworksheet = workbook.add_worksheet()\n\narray = result\n\nrow = 0\n\nfor col, data in enumerate(array):\n    worksheet.write_column(row, col, data)\n\nworkbook.close()"

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0ac921c19f1a> in <module>()
# ----> 1 result
#
# NameError: name 'result' is not defined
